# %%
tickers = ['AAPL','JPM','F','PG', 'BA']

investment_period = 1 # each 1 investment days 
reward_period = 15 # each 15 investment periods
discount = 0.9

# %%
from environments.benchmark import create_env_benchmark
from environments.util import fetch_observations
from environments.max_gain import create_env_max_gain
from environments.paper import create_env_paper
from stable_baselines3 import SAC

prices,benchmark, observations, dates = fetch_observations(tickers,investment_period,'1992-01-01','2016-12-31')

envs = [
        create_env_paper(prices,benchmark,observations,reward_period),
        create_env_max_gain(prices,observations,reward_period,0),
        create_env_max_gain(prices,observations,reward_period,0.25),
        create_env_max_gain(prices,observations,reward_period,0.5),
        create_env_max_gain(prices,observations,reward_period,0.75),
        create_env_max_gain(prices,observations,reward_period,1),
        create_env_benchmark(prices,benchmark,observations,reward_period,0),
        create_env_benchmark(prices,benchmark,observations,reward_period,0.25),
        create_env_benchmark(prices,benchmark,observations,reward_period,0.5),
        create_env_benchmark(prices,benchmark,observations,reward_period,0.75),
        create_env_benchmark(prices,benchmark,observations,reward_period,1)
]

# %%
learning_rate=0.001

for idx,env in enumerate(envs):
    model = SAC(policy='MlpPolicy', env=env, verbose=1, learning_rate=learning_rate, gamma=discount)
    model.learn(total_timesteps=20000)
    save_file_name = model.__class__.__name__ + f'_env_{idx}.zip'
    model.save(f'./models/{save_file_name}')
    del model
# Out:
# Using cpu device
# d:\.war\satan\.venv\Lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 1.15GB > 0.74GB
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 learning_rate=0.001
#       3 for idx,env in enumerate(envs):
# ----> 4     model = SAC(policy='MlpPolicy', env=env, verbose=1, learning_rate=learning_rate, gamma=discount)
#       5     model.learn(total_timesteps=20000)
#       6     save_file_name = model.__class__.__name__ + f'_env_{idx}.zip'
#
# File d:\.war\satan\.venv\Lib\site-packages\stable_baselines3\sac\sac.py:157, in SAC.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, action_noise, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, ent_coef, target_update_interval, target_entropy, use_sde, sde_sample_freq, use_sde_at_warmup, stats_window_size, tensorboard_log, policy_kwargs, verbose, seed, device, _init_setup_model)
#     154 self.ent_coef_optimizer: Optional[th.optim.Adam] = None
#     156 if _init_setup_model:
# --> 157     self._setup_model()
#
# File d:\.war\satan\.venv\Lib\site-packages\stable_baselines3\sac\sac.py:160, in SAC._setup_model(self)
#     159 def _setup_model(self) -> None:
# --> 160     super()._setup_model()
#     161     self._create_aliases()
#     162     # Running mean and running var
#
# File d:\.war\satan\.venv\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:199, in OffPolicyAlgorithm._setup_model(self)
#     188         replay_buffer_kwargs["env"] = self.env
#     189     self.replay_buffer = self.replay_buffer_class(
#     190         self.buffer_size,
#     191         self.observation_space,
#    (...)
#     196         **replay_buffer_kwargs,
#     197     )
# --> 199 self.policy = self.policy_class(
#     200     self.observation_space,
#     201     self.action_space,
#     202     self.lr_schedule,
#     203     **self.policy_kwargs,
#     204 )
#     205 self.policy = self.policy.to(self.device)
#     207 # Convert train freq parameter to TrainFreq object
#
# File d:\.war\satan\.venv\Lib\site-packages\stable_baselines3\sac\policies.py:278, in SACPolicy.__init__(self, observation_space, action_space, lr_schedule, net_arch, activation_fn, use_sde, log_std_init, use_expln, clip_mean, features_extractor_class, features_extractor_kwargs, normalize_images, optimizer_class, optimizer_kwargs, n_critics, share_features_extractor)
#     268 self.critic_kwargs.update(
#     269     {
#     270         "n_critics": n_critics,
#    (...)
#     273     }
#     274 )
#     276 self.share_features_extractor = share_features_extractor
# --> 278 self._build(lr_schedule)
#
# File d:\.war\satan\.venv\Lib\site-packages\stable_baselines3\sac\policies.py:282, in SACPolicy._build(self, lr_schedule)
#     280 def _build(self, lr_schedule: Schedule) -> None:
#     281     self.actor = self.make_actor()
# --> 282     self.actor.optimizer = self.optimizer_class(
#     283         self.actor.parameters(),
#     284         lr=lr_schedule(1),  # type: ignore[call-arg]
#     285         **self.optimizer_kwargs,
#     286     )
#     288     if self.share_features_extractor:
#     289         self.critic = self.make_critic(features_extractor=self.actor.features_extractor)
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\optim\adam.py:78, in Adam.__init__(self, params, lr, betas, eps, weight_decay, amsgrad, foreach, maximize, capturable, differentiable, fused)
#      64     raise ValueError(f"Invalid weight_decay value: {weight_decay}")
#      66 defaults = dict(
#      67     lr=lr,
#      68     betas=betas,
#    (...)
#      76     fused=fused,
#      77 )
# ---> 78 super().__init__(params, defaults)
#      80 if fused:
#      81     if differentiable:
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\optim\optimizer.py:371, in Optimizer.__init__(self, params, defaults)
#     368     param_groups = [{"params": param_groups}]
#     370 for param_group in param_groups:
# --> 371     self.add_param_group(cast(dict, param_group))
#     373 # Allows _cuda_graph_capture_health_check to rig a poor man's TORCH_WARN_ONCE in python,
#     374 # which I don't think exists
#     375 # https://github.com/pytorch/pytorch/issues/72948
#     376 self._warned_capturable_if_run_uncaptured = True
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\_compile.py:27, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      25 disable_fn = getattr(fn, "__dynamo_disable", None)
#      26 if disable_fn is None:
# ---> 27     import torch._dynamo
#      29     disable_fn = torch._dynamo.disable(fn, recursive)
#      30     fn.__dynamo_disable = disable_fn
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\_dynamo\__init__.py:3
#       1 import torch
# ----> 3 from . import convert_frame, eval_frame, resume_execution
#       4 from .backends.registry import list_backends, lookup_backend, register_backend
#       5 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\_dynamo\convert_frame.py:53
#      47 from torch.utils._python_dispatch import (
#      48     _disable_current_modes,
#      49     is_in_torch_dispatch_mode,
#      50 )
#      51 from torch.utils._traceback import CapturedTraceback, format_traceback_short
# ---> 53 from . import config, exc, trace_rules
#      54 from .bytecode_analysis import remove_dead_code, remove_pointless_jumps
#      55 from .bytecode_transformation import (
#      56     check_inst_exn_tab_entries_valid,
#      57     Instruction,
#    (...)
#      60     transform_code_object,
#      61 )
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\_dynamo\trace_rules.py:46
#      44 from .resume_execution import TORCH_DYNAMO_RESUME_IN_PREFIX
#      45 from .utils import getfile, hashable, NP_SUPPORTED_MODULES, unwrap_if_wrapper
# ---> 46 from .variables import (
#      47     BuiltinVariable,
#      48     FunctionalCallVariable,
#      49     FunctorchHigherOrderVariable,
#      50     NestedUserFunctionVariable,
#      51     PolyfilledFunctionVariable,
#      52     SkipFunctionVariable,
#      53     TorchInGraphFunctionVariable,
#      54     UserFunctionVariable,
#      55     UserMethodVariable,
#      56 )
#      59 np: Optional[types.ModuleType] = None
#      60 try:
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\_dynamo\variables\__init__.py:39
#      30 from .distributed import BackwardHookVariable, DistributedVariable, PlacementVariable
#      31 from .functions import (
#      32     FunctoolsPartialVariable,
#      33     NestedUserFunctionVariable,
#    (...)
#      37     UserMethodVariable,
#      38 )
# ---> 39 from .higher_order_ops import (
#      40     FunctionalCallVariable,
#      41     FunctorchHigherOrderVariable,
#      42     TorchHigherOrderOperatorVariable,
#      43 )
#      44 from .iter import (
#      45     CountIteratorVariable,
#      46     CycleIteratorVariable,
#    (...)
#      51     ZipVariable,
#      52 )
#      53 from .lazy import LazyVariableTracker
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\_dynamo\variables\higher_order_ops.py:14
#      12 import torch.fx
#      13 import torch.nn
# ---> 14 import torch.onnx.operators
#      15 from torch._dynamo.utils import get_fake_value
#      16 from torch._dynamo.variables import ConstantVariable
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\onnx\__init__.py:71
#      69 from ._type_utils import JitScalarType
#      70 from .errors import OnnxExporterError
# ---> 71 from .utils import (
#      72     _optimize_graph,
#      73     _run_symbolic_function,
#      74     _run_symbolic_method,
#      75     export_to_pretty_string,
#      76     is_in_onnx_export,
#      77     register_custom_op_symbolic,
#      78     select_model_mode_for_export,
#      79     unregister_custom_op_symbolic,
#      80 )
#      83 from . import (  # usort: skip. Keep the order instead of sorting lexicographically
#      84     errors,
#      85     symbolic_caffe2,
#    (...)
#     101     utils,
#     102 )
#     105 from ._internal._exporter_legacy import (  # usort: skip. needs to be last to avoid circular import
#     106     DiagnosticOptions,
#     107     ExportOptions,
#    (...)
#     111     enable_fake_mode,
#     112 )
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\onnx\utils.py:31
#      23 from torch.onnx import (  # noqa: F401
#      24     _constants,
#      25     _deprecation,
#    (...)
#      28     symbolic_helper,
#      29 )
#      30 from torch.onnx._globals import GLOBALS
# ---> 31 from torch.onnx._internal import diagnostics, jit_utils, onnx_proto_utils, registration
#      34 __all__ = [
#      35     "is_in_onnx_export",
#      36     "select_model_mode_for_export",
#    (...)
#      47     "unregister_custom_op_symbolic",
#      48 ]
#      51 def is_in_onnx_export() -> bool:
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\onnx\_internal\diagnostics\__init__.py:1
# ----> 1 from ._diagnostic import (
#       2     create_export_diagnostic_context,
#       3     diagnose,
#       4     engine,
#       5     export_context,
#       6     ExportDiagnosticEngine,
#       7     TorchScriptOnnxExportDiagnostic,
#       8 )
#       9 from ._rules import rules
#      10 from .infra import levels
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\onnx\_internal\diagnostics\_diagnostic.py:11
#       8 from typing import TYPE_CHECKING
#      10 import torch
# ---> 11 from torch.onnx._internal.diagnostics import infra
#      12 from torch.onnx._internal.diagnostics.infra import formatter, sarif
#      13 from torch.onnx._internal.diagnostics.infra.sarif import version as sarif_version
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\onnx\_internal\diagnostics\infra\__init__.py:1
# ----> 1 from ._infra import (
#       2     DiagnosticOptions,
#       3     Graph,
#       4     Invocation,
#       5     Level,
#       6     levels,
#       7     Location,
#       8     Rule,
#       9     RuleCollection,
#      10     Stack,
#      11     StackFrame,
#      12     Tag,
#      13     ThreadFlowLocation,
#      14 )
#      15 from .context import Diagnostic, DiagnosticContext, RuntimeErrorWithDiagnostic
#      18 __all__ = [
#      19     "Diagnostic",
#      20     "DiagnosticContext",
#    (...)
#      33     "ThreadFlowLocation",
#      34 ]
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\onnx\_internal\diagnostics\infra\_infra.py:11
#       8 import logging
#       9 from typing import Mapping, Sequence
# ---> 11 from torch.onnx._internal.diagnostics.infra import formatter, sarif
#      14 class Level(enum.IntEnum):
#      15     """The level of a diagnostic.
#      16
#      17     This class is used to represent the level of a diagnostic. The levels are defined
#    (...)
#      34         Level.ERROR = logging.ERROR = 40
#      35     """
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\onnx\_internal\diagnostics\infra\formatter.py:10
#       7 from typing import Any, Callable, Union
#       9 from torch._logging import LazyString
# ---> 10 from torch.onnx._internal.diagnostics.infra import sarif
#      13 # A list of types in the SARIF module to support pretty printing.
#      14 # This is solely for type annotation for the functions below.
#      15 _SarifClass = Union[
#      16     sarif.SarifLog,
#      17     sarif.Run,
#      18     sarif.ReportingDescriptor,
#      19     sarif.Result,
#      20 ]
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\onnx\_internal\diagnostics\infra\sarif\__init__.py:14
#      10 from torch.onnx._internal.diagnostics.infra.sarif._artifact_location import (
#      11     ArtifactLocation,
#      12 )
#      13 from torch.onnx._internal.diagnostics.infra.sarif._attachment import Attachment
# ---> 14 from torch.onnx._internal.diagnostics.infra.sarif._code_flow import CodeFlow
#      15 from torch.onnx._internal.diagnostics.infra.sarif._configuration_override import (
#      16     ConfigurationOverride,
#      17 )
#      18 from torch.onnx._internal.diagnostics.infra.sarif._conversion import Conversion
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\onnx\_internal\diagnostics\infra\sarif\_code_flow.py:9
#       6 import dataclasses
#       7 from typing import List, Optional
# ----> 9 from torch.onnx._internal.diagnostics.infra.sarif import (
#      10     _message,
#      11     _property_bag,
#      12     _thread_flow,
#      13 )
#      16 @dataclasses.dataclass
#      17 class CodeFlow(object):
#      18     """A set of threadFlows which together describe a pattern of code execution relevant to detecting a result."""
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\onnx\_internal\diagnostics\infra\sarif\_thread_flow.py:9
#       6 import dataclasses
#       7 from typing import Any, List, Optional
# ----> 9 from torch.onnx._internal.diagnostics.infra.sarif import (
#      10     _message,
#      11     _property_bag,
#      12     _thread_flow_location,
#      13 )
#      16 @dataclasses.dataclass
#      17 class ThreadFlow(object):
#      18     """Describes a sequence of code locations that specify a path through a single thread of execution such as an operating system or fiber."""
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\onnx\_internal\diagnostics\infra\sarif\_thread_flow_location.py:9
#       6 import dataclasses
#       7 from typing import Any, List, Literal, Optional
# ----> 9 from torch.onnx._internal.diagnostics.infra.sarif import (
#      10     _location,
#      11     _property_bag,
#      12     _reporting_descriptor_reference,
#      13     _stack,
#      14     _web_request,
#      15     _web_response,
#      16 )
#      19 @dataclasses.dataclass
#      20 class ThreadFlowLocation(object):
#      21     """A location visited by an analysis tool while simulating or monitoring the execution of a program."""
#
# File d:\.war\satan\.venv\Lib\site-packages\torch\onnx\_internal\diagnostics\infra\sarif\_stack.py:9
#       6 import dataclasses
#       7 from typing import List, Optional
# ----> 9 from torch.onnx._internal.diagnostics.infra.sarif import (
#      10     _message,
#      11     _property_bag,
#      12     _stack_frame,
#      13 )
#      16 @dataclasses.dataclass
#      17 class Stack(object):
#      18     """A call stack that is relevant to a result."""
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:1080, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1504, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1476, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1612, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:147, in _path_stat(path)
#
# KeyboardInterrupt:
